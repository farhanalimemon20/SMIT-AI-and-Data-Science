# %% [markdown]
# <a href="https://colab.research.google.com/github/farhanalimemon20/SMIT-AI-and-Data-Science/blob/homework/Homework_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Home Work: 2
# ## Date: 9/11/2025
# ## Instructor: Sir Shanawaz Qureshi
# ## Name: Farhan Ali Memon
# ## City: Shikarpur
# ## Classes: Sat-Sun ; 12pm-2pm

# %% [markdown]
# 🏫 1. Classroom Grading Assistant
#
# You’re making an app for your teacher.
# Ask for a student’s marks (out of 100):
#
# If ≥ 90 → “Topper of the class 🎓”
#
# 75–89 → “Excellent effort 💪”
#
# 50–74 → “Keep improving 📘”
#
# Below 50 → “Needs extra support 📉”

# %%
marks = int(input("Enter your marks: "))
print("Your Marks:",marks)
if marks >= 90:
  print("Topper of the class")
elif marks >= 75:
  print("Excellent effort")
elif marks >= 50:
  print("Keep improving")
else:
  print("Needs extra support")
# Out:
# Enter your marks: 4
# Your Marks: 4
# Needs extra support

# %% [markdown]
# ☕ 2. Coffee Machine Logic
#
# A café machine takes the customer’s choice: 1 for Tea, 2 for Coffee, 3 for Hot Chocolate.
#
# If choice = 1 → “Here’s your Tea 🍵”
#
# If choice = 2 → “Here’s your Coffee ☕”
#
# If choice = 3 → “Hot Chocolate coming up 🍫”
#
# Else → “Invalid selection ❌”
#
#
# (Challenge them to handle invalid inputs)

# %%
choice = int(input("Enter your choice (1 for Tea, 2 for Coffee, 3 for Hot Chocolate): "))
if choice == 1:
  print("Here’s your Tea ")
elif choice == 2:
  print("Here’s your Coffee ")
elif choice == 3:
  print("Hot Chocolate coming up ")
else:
    print("Invalid selection ")
# Out:
# Enter your choice (1 for Tea, 2 for Coffee, 3 for Hot Chocolate): 1
# Here’s your Tea

# %% [markdown]
# 🚦 3. Smart Traffic Light
#
# A smart signal reads the color: "red", "yellow", or "green".
#
# "red" → “STOP 🚫”
#
# "yellow" → “READY ⚠”
#
# "green" → “GO ✅”
# Else print “Signal malfunction 🚨”.
#
#
# (They can extend with nested if for “pedestrian mode”)

# %%
light_color = input("Enter signal color: ")
if light_color == "red":
  print("STOP")
elif light_color == "yellow":
  print("READY")
elif light_color == "green":
  print("GO")
else:
  print("Please Enter correct signal color")
# Out:
# Enter signal color: red
# STOP

# %% [markdown]
# 🎢 4. Theme Park Entry System
#
# Ask user for age and height.
#
# Must be ≥ 12 years and height ≥ 120 cm → “You can ride 🎡”
#
# Else if age < 12 → “Too young 🙅”
#
# Else if height < 120 → “Too short for safety 🚷”
#
#
# (Combines and + elif)

# %%
age = int(input("Enter your age: "))
height = int(input("Enter your height in cm: "))
if age >= 12 and height >= 120:
  print("You can ride")
elif age < 12:
  print("Too young")
elif height < 120:
  print("Too short for safety")
# Out:
# Enter your age: 18
# Enter your height in cm: 130
# You can ride

# %% [markdown]
# 🍕 5. Pizza Order Discount
#
# Ask for pizza size: "small", "medium", "large".
# Ask if they have a coupon: "yes" or "no".
#
# If "large" and coupon = "yes" → 20% discount
#
# If "medium" → 10% discount
#
# If "small" → 5% discount
# Else → “Invalid size!”
#
#
# (Mixes multiple conditions and string comparison)

# %%
pizza_size = (input("Please enter size of your pizza: "))
coupon = input("Do you hava a coupon ? :")
if pizza_size == "large" and coupon == "yes":
  print("20% discount")
elif pizza_size == "medium" and coupon == "yes":
  print("10% discount")
elif pizza_size == "small" and coupon == "yes":
  print("5% discount")
else:
  print("Invalid size")
# Out:
# Please enter size of your pizza: small
# Do you hava a coupon ? :yes
# 5% discount

# %% [markdown]
# 💳 6. ATM Transaction
#
# Ask user for pin and balance.
#
# If pin == 1234 and balance ≥ 500 → “Withdrawal successful 💸”
#
# If pin != 1234 → “Incorrect PIN 🔒”
#
# If balance < 500 → “Insufficient funds 💰”
#
#
# (For bonus: nest the balance check inside pin check)
#
#
# ---

# %%
pin = input("Enter your pin: ")
balance = int(input("Enter your balance: "))
if pin == "1234" and balance >= 500:
  print("Withdrawal successful")
elif pin != "1234":
  print("Incorrect PIN")
elif balance < 500:
  print("Insufficient funds")
# Out:
# Enter your pin: 1234
# Enter your balance: 500
# Withdrawal successful

# %% [markdown]
# 🏖 7. Vacation Recommender
#
# Ask user for season: "summer", "winter", "spring", "autumn".
# Print destination suggestion:
#
# "summer" → “Go to the beach 🏖”
#
# "winter" → “Let’s hit the mountains 🏔”
#
# "spring" → “Visit the gardens 🌸”
#
# "autumn" → “Take a forest hike 🍂”
# Else → “Invalid season entered.”

# %%
season = input("Enter your season: ")
if season == "summer":
  print("Go to the beach")
elif season == "winter":
  print("Let's hit the mountains")
elif season == "spring":
  print("Visit the gardens")
elif season == "autumn":
  print("Take a forest hike")
else:
  print("Invalid season entered")
# Out:
# Enter your season: summer
# Go to the beach

# %% [markdown]
# 🚗 8. Speed Limit Monitor
#
# Ask for driver speed:
#
# < 40 → “Too slow, keep moving 🐢”
#
# 40–80 → “Safe speed 🚗”
#
# 81–120 → “Warning! Overspeed ⚠”
#
#   if > 120 → “License suspended 🚓”
#
#
#
#
# (Encourage them to use compound comparison 40 <= speed <= 80)

# %%
speed = int(input("Enter your speed: "))
if speed <40:
  print("Too slow, keep moving")
elif speed >= 40 and speed <= 80:
  print("Safe speed")
elif speed >= 81 and speed <= 120:
  print("Warninng! Overspeed")
elif speed > 120:
  print("License suspended")
# Out:
# Enter your speed: 60
# Safe speed

# %% [markdown]
# 🏨 9. Hotel Room Booking
#
# Ask user for number of nights and room type ("standard", "deluxe", "suite").
#
# If "suite" and nights ≥ 3 → “Luxury discount applied 🏆”
#
# If "deluxe" → “Breakfast included 🍳”
#
# If "standard" → “Basic stay 🛏”
# Else → “Invalid room type.”

# %%
nights = int(input("Enter number of nights: "))
room_type = input("Enter room type: ")
if room_type == "suite" and nights >= 3:
  print("Luxury discount applied")
elif room_type == "deluxe":
  print("Breakfast included")
elif room_type == "standard":
  print("Basic stay")
else:
  print("Invalid room type")
# Out:
# Enter number of nights: 3
# Enter room type: suite
# Luxury discount applied

# %% [markdown]
# 👾 10. Gaming Level Unlock
#
# A player inputs their score and coins.
#
# If score ≥ 1000 and coins ≥ 50 → “Next Level Unlocked 🎮”
#
# If score ≥ 500 → “Halfway there 🔥”
#
# Else → “Keep playing 💪”

# %%
score = int(input("Enter your score: "))
coins = int(input("Enter your coins: "))
if score >= 1000 and coins >= 50:
  print("Next Level Unlocked")
elif score >= 500:
  print("Halfway there")
else:
  print("Keep Moving")
# Out:
# Enter your score: 69
# Enter your coins: 5000
# Keep Moving

# %% [markdown]
# Completion
# >Time: 9:50
#
# >Date: 9/11/2025
